# %% [markdown]
# ### Extract Kialo Debate Data
#
# Parses raw Kialo text files to extract structured debate data: discussion names, arguments (Pro/Con), sources, and hierarchical node IDs (e.g., `1.2.3`).

# %%
from langdetect import detect

def is_english_text(text: str) -> bool:
    try:
        return detect(text) == "en"
    except:
        return False

# %%
import pandas as pd
import re
import os
import nltk
from nltk.corpus import stopwords

nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

def parse_kialo_txt(path):
    with open(path, "r", encoding="utf-8") as f:
        lines = [l.rstrip("\n") for l in f]

    discussion_name = None
    rows = []
    sources = {}
    in_sources = False

    # First pass: collect sources
    for i, line in enumerate(lines):
        if line.strip().startswith("Sources:"):
            in_sources = True
            continue
        if in_sources:
            match = re.match(r"\[(\d+)\]\s+(\S+)", line)
            if match:
                idx, url = match.groups()
                sources[idx] = url

    # Second pass: parse arguments
    for i, line in enumerate(lines):
        if line.startswith("Discussion Name:"):
            discussion_name = lines[i+1].strip()
        match = re.match(r"\s*(\d+(?:\.\d+)*)\.\s*(Pro|Con):\s*$", line)
        if match:
            node_id, stance = match.groups()
            j = i + 1
            while j < len(lines) and lines[j].strip() == "":
                j += 1
            argument = lines[j].strip() if j < len(lines) else ""
            refs = re.findall(r"\[(\d+)\]", argument)
            urls = [sources[r] for r in refs if r in sources]
            clean_argument = re.sub(r"\[\d+\]", "", argument).strip()
            rows.append({
                "discussion": discussion_name,
                "node_id": node_id,
                "stance": stance,
                "argument": clean_argument,
                "sources": urls
            })
    return pd.DataFrame(rows)

data_dir = "../../data/kialo/debates"
all_files = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if f.endswith(".txt")]

dfs = []
for f in all_files:
    filename = os.path.basename(f)
    if not is_english_text(filename):
        print(f"Skipping non-English file: {filename}")
        continue
    try:
        dfs.append(parse_kialo_txt(f))
    except Exception as e:
        print(f"Error with {f}: {e}")

full_df = pd.concat(dfs, ignore_index=True)
print("Total number of arguments:", len(full_df))
full_df
# Out:
# [nltk_data] Downloading package stopwords to /home/nysek/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Skipping non-English file: does-god-exist-2629 (1).txt
# Skipping non-English file: is-an-omnimalevolent-god-as-plausible-as-an-omnibenevolent-god-51497.txt
# Skipping non-English file: are-ufos-real-64046.txt
# Skipping non-English file: warum-gibt-es-leid-auf-der-welt-wenn-es-einen-liebenden-allmächtigen-gott-gibt-43228.txt
# Skipping non-English file: are-women-better-than-men-26866.txt
# Skipping non-English file: le-macchine-possono-pensare-42870.txt
# Skipping non-English file: do-gun-control-laws-reduce-crime-8319.txt
# Skipping non-English file: quale-partito-dovrebbero-votare-gli-italiani-alle-prossime-elezioni-politiche-9131.txt
# Skipping non-English file: does-religion-misguide-people-31753.txt
# Skipping non-English file: la-eutanasia-podria-ser-viable-en-españa-52324 (1).txt
# Skipping non-English file: are-video-games-art-27596.txt
# Skipping non-English file: religia-nie-powinna-być-przedmiotem-szkolnym-32840 (1).txt
# Skipping non-English file: was-sind-die-effektivsten-aktionsformen-gegen-rechtsextremismus-in-deutschland-2024-66644.txt
# Skipping non-English file: do-covalent-bonds-have-preferable-qualities-for-human-survival-31653.txt
# Skipping non-English file: does-pineapple-belong-on-pizza-10104.txt
# Skipping non-English file: le-tirage-au-sort-des-parlementaires-est-il-une-alternative-souhaitable-à-lélection--50716.txt
# Skipping non-English file: i-corsi-di-laurea-in-medicina-dovrebbero-essere-ad-accesso-libero-25902.txt
# Skipping non-English file: triangles-arent-a-real-instrument-58025.txt
# Skipping non-English file: sollten-wir-unseren-fleischkonsum-deutlich-einschränken-55560.txt
# Skipping non-English file: warum-gibt-es-leid-auf-der-welt-wenn-es-einen-liebenden-allmächtigen-gott-gibt-43228 (1).txt
# Skipping non-English file: was-sind-die-wichtigsten-probleme-die-die-deutsche-politik-lösen-sollte-41790.txt
# Skipping non-English file: tabs-vs-spaces-16646 (1).txt
# Skipping non-English file: i-corsi-di-laurea-in-medicina-dovrebbero-essere-ad-accesso-libero-25902 (1).txt
# Skipping non-English file: bajar-los-impuestos-en-españa-crea-riqueza-28436.txt
# Skipping non-English file: gender-stereotyping-in-advertising-should-be-banned-10074.txt
# Skipping non-English file: digital-piracy-good-or-bad-11289 (1).txt
# Skipping non-English file: religia-nie-powinna-być-przedmiotem-szkolnym-32840.txt
# Skipping non-English file: does-god-exist-2629.txt
# Skipping non-English file: the-feminism-question-58694.txt
# Skipping non-English file: do-humans-need-man-made-borders-32909 (1).txt
# Skipping non-English file: la-chiesa-cattolica-esercita-una-eccessiva-ingerenza-sullo-stato-italiano-56974.txt
# Skipping non-English file: 您是否同意核四啟封商轉發電？-55122 (1).txt
# Skipping non-English file: do-humans-need-man-made-borders-32909.txt
# Skipping non-English file: sollten-wir-unseren-fleischkonsum-deutlich-einschränken-55560 (1).txt
# Skipping non-English file: il-faut-empêcher-langlais-au-québec-20989.txt
# Skipping non-English file: la-eutanasia-podria-ser-viable-en-españa-52324.txt
# Skipping non-English file: did-thanos-do-anything-wrong-21532.txt
# Skipping non-English file: inzest-sollte-legalisiert-werden-52701 (1).txt
# Skipping non-English file: ¿qué-es-el-arte-41541 (1).txt
# Skipping non-English file: is-artificial-general-intelligence-agi-even-possible-27150.txt
# Skipping non-English file: die-afd-steht-dem-nationalsozialistischem-gedankengut-nahe-22314 (1).txt
# Skipping non-English file: a-ação-humana-e-a-compreensão-de-agir-46831 (1).txt
# Skipping non-English file: a-ação-humana-e-a-compreensão-de-agir-46831.txt
# Skipping non-English file: bajar-los-impuestos-en-españa-crea-riqueza-28436 (1).txt
# Skipping non-English file: digital-piracy-good-or-bad-11289.txt
# Skipping non-English file: ¿qué-es-el-arte-41541.txt
# Skipping non-English file: tabs-vs-spaces-16646.txt
# Skipping non-English file: vale-imparare-litaliano-come-lingua-straniera-20986.txt
# Skipping non-English file: was-sind-die-wichtigsten-probleme-die-die-deutsche-politik-lösen-sollte-41790 (1).txt
# Skipping non-English file: donald-trump-for-president-2024-65105.txt
# Skipping non-English file: best-science-fiction-movie-1257.txt
# Skipping non-English file: should-president-biden-forgive-all-us-student-debt-63097 (1).txt
# Skipping non-English file: does-religion-misguide-people-31753 (1).txt
# Skipping non-English file: die-afd-steht-dem-nationalsozialistischem-gedankengut-nahe-22314.txt
# Skipping non-English file: is-water-wet-6298.txt
# Skipping non-English file: is-artificial-general-intelligence-agi-even-possible-27150 (1).txt
# Skipping non-English file: should-president-biden-forgive-all-us-student-debt-63097.txt
# Skipping non-English file: is-premarital-sex-immoral-47027.txt
# Skipping non-English file: 您是否同意核四啟封商轉發電？-55122.txt
# Skipping non-English file: is-killing-vampires-immoral-4839.txt
# Skipping non-English file: inzest-sollte-legalisiert-werden-52701.txt
# Skipping non-English file: best-science-fiction-movie-1257 (1).txt
# Skipping non-English file: wird-die-coronavirus-pandemie-langfristige-auswirkungen-auf-die-gesellschaft-haben-40660.txt
# Skipping non-English file: están-preparados-los-estudiantes-para-el-método-de-aula-invertida-41530.txt
# Total number of arguments: 205672
#                                  discussion node_id stance  \
# 0          "Collective Unconscious" is real     1.1    Con
# 1          "Collective Unconscious" is real   1.1.1    Pro
# 2          "Collective Unconscious" is real     1.2    Con
# 3          "Collective Unconscious" is real     1.3    Pro
# 4          "Collective Unconscious" is real     1.4    Pro
# ...                                     ...     ...    ...
# 205667  Would A Cashless Society Be Better?  1.11.3    Pro
# 205668  Would A Cashless Society Be Better?  1.11.4    Pro
# 205669  Would A Cashless Society Be Better?    1.12    Con
# 205670  Would A Cashless Society Be Better?  1.12.1    Pro
# 205671  Would A Cashless Society Be Better?  1.12.2    Pro
#
#                                                  argument sources
# 0       Archetypes is a human word describing a widely...      []
# 1       Humans, being alike from any animal, have comp...      []
# 2       There are a wide range that people are exposed...      []
# 3       Collective Intelligence is real and it is test...      []
# 4       The similarity between all religions prove tha...      []
# ...                                                   ...     ...
# 205667  People lose money. The amount of lost money un...      []
# 205668  Service and item bartering would regain popula...      []
# 205669  Cash is important for the the grey economy or ...      []
# 205670  Without an anonymous means to transact, no cur...      []
# 205671  A cashless society would hurt the livelihoods ...      []
#
# [205672 rows x 5 columns]

# %% [markdown]
# We can see that some english debates are detected as non english, but we already have a lot of data, so it's not a big problem.

# %% [markdown]
# ### Create Parent-Child Pairs
#
# Generates pairs of connected arguments (parent -> child) and labels their relationship as **Support** (same stance) or **Attack** (opposing stances).

# %%
def create_parent_child_pairs(df):
    """
    Creates parent/child pairs from Kialo data
    """
    pairs = []
    
    # Group by discussion to process each debate separately
    for discussion_name, group in df.groupby('discussion'):
        # Create dictionary for quick access by node_id
        nodes = {row['node_id']: row for _, row in group.iterrows()}
        
        # For each node, find its parent
        for _, child_row in group.iterrows():
            child_id = child_row['node_id']
            parent_id = find_parent_id(child_id)
            
            # If we find a parent in the data
            if parent_id and parent_id in nodes:
                parent_row = nodes[parent_id]
                
                # Determine relation based on stances
                relation = determine_relation(parent_row['stance'], child_row['stance'])
                
                pairs.append({
                    'discussion': discussion_name,
                    'parent_node_id': parent_id,
                    'parent_argument': parent_row['argument'],
                    'parent_stance': parent_row['stance'],
                    'child_node_id': child_id,
                    'child_argument': child_row['argument'],
                    'child_stance': child_row['stance'],
                    'relation': relation
                })
    
    return pd.DataFrame(pairs)

def find_parent_id(node_id):
    """
    Finds the parent ID of a given node
    Ex: 1.2.3 -> 1.2, 1.5 -> 1, 2.1.4.2 -> 2.1.4
    """
    parts = node_id.split('.')
    if len(parts) <= 1:
        return None  # No parent (root node)
    
    # Return parent ID (all parts except the last one)
    return '.'.join(parts[:-1])

def determine_relation(parent_stance, child_stance):
    """
    Determines if the relation is Support or Attack based on stances
    
    In Kialo:
    - If parent and child have same stance -> Support
    - If parent and child have different stances -> Attack
    """
    if parent_stance == 'Pro':
        if child_stance == 'Pro':
            return 'Support'
        else:
            return 'Attack'
    if parent_stance == 'Con':
        if child_stance == 'Pro':
            return 'Support'
        else:
            return 'Attack'

# Usage with your data
pairs_df = create_parent_child_pairs(full_df)

print(f"Total number of pairs created: {len(pairs_df)}")

# Relation verification
print(f"\nRelation distribution:")
print(pairs_df['relation'].value_counts())

# Example of Support relation
print(f"\nExample of Support relation:")
support_example = pairs_df[pairs_df['relation'] == 'Support'].iloc[0] if len(pairs_df[pairs_df['relation'] == 'Support']) > 0 else None
if support_example is not None:
    print(f"Parent ({support_example['parent_stance']}): {support_example['parent_argument'][:100]}...")
    print(f"Child ({support_example['child_stance']}): {support_example['child_argument'][:100]}...")

# Example of Attack relation
print(f"\nExample of Attack relation:")
attack_example = pairs_df[pairs_df['relation'] == 'Attack'].iloc[0] if len(pairs_df[pairs_df['relation'] == 'Attack']) > 0 else None
if attack_example is not None:
    print(f"Parent ({attack_example['parent_stance']}): {attack_example['parent_argument'][:100]}...")
    print(f"Child ({attack_example['child_stance']}): {attack_example['child_argument'][:100]}...")

pairs_df
# Out:
# Total number of pairs created: 197831
#
# Relation distribution:
# relation
# Attack     100470
# Support     97361
# Name: count, dtype: int64
#
# Example of Support relation:
# Parent (Con): The pharmacy chain is convoluted and deeply resistant to regulation through lobbying efforts...
# Child (Pro): Spending on pharmaceutical industry lobbying reached a record amount in 2020, at more than $306 mill...
#
# Example of Attack relation:
# Parent (Pro): These manufacturers invest billions into R&D that contributes toward new therapies every year that i...
# Child (Con): A substantial portion of Research and Development (R&D) is financed through government grants, yet t...
#                                                discussion parent_node_id  \
# 0               "Big pharma" is actually good for society            1.1
# 1               "Big pharma" is actually good for society            1.1
# 2               "Big pharma" is actually good for society            1.3
# 3               "Big pharma" is actually good for society            1.3
# 4               "Big pharma" is actually good for society            1.3
# ...                                                   ...            ...
# 197826  Would the world be a better place without humans?          1.4.4
# 197827  Would the world be a better place without humans?        1.4.4.2
# 197828  Would the world be a better place without humans?        1.4.4.2
# 197829  Would the world be a better place without humans?        1.4.4.2
# 197830  Would the world be a better place without humans?      1.4.4.2.3
#
#                                           parent_argument parent_stance  \
# 0       The pharmacy chain is convoluted and deeply re...           Con
# 1       The pharmacy chain is convoluted and deeply re...           Con
# 2       These manufacturers invest billions into R&D t...           Pro
# 3       These manufacturers invest billions into R&D t...           Pro
# 4       These manufacturers invest billions into R&D t...           Pro
# ...                                                   ...           ...
# 197826  According to the word of God in Genesis 1 , hu...           Con
# 197827  The Bible is not a credible source of informat...           Con
# 197828  The Bible is not a credible source of informat...           Con
# 197829  The Bible is not a credible source of informat...           Con
# 197830  Many of the kingdoms and cities  in the Old Te...           Con
#
#        child_node_id                                     child_argument  \
# 0              1.1.1  Spending on pharmaceutical industry lobbying r...
# 1              1.1.2  In 2020 there were 1,500 pharmaceutical lobbyi...
# 2              1.3.1  Diseases from hemophilia to cancer to autoimmu...
# 3              1.3.2  Likely the most efficient way to motivate cont...
# 4              1.3.3  A substantial portion of Research and Developm...
# ...              ...                                                ...
# 197826       1.4.4.2  The Bible is not a credible source of informat...
# 197827     1.4.4.2.1  Due to the age of the Bible and the fact that ...
# 197828     1.4.4.2.2  The Bible was written by humans , not a divine...
# 197829     1.4.4.2.3  Many of the kingdoms and cities  in the Old Te...
# 197830   1.4.4.2.3.1  Some aspects of stories can be true without th...
#
#        child_stance relation
# 0               Pro  Support
# 1               Pro  Support
# 2               Pro  Support
# 3               Pro  Support
# 4               Con   Attack
# ...             ...      ...
# 197826          Con   Attack
# 197827          Pro  Support
# 197828          Pro  Support
# 197829          Con   Attack
# 197830          Con   Attack
#
# [197831 rows x 8 columns]

# %% [markdown]
# ### Simplify DataFrame
#
# Removes unnecessary columns (e.g., discussion names, node IDs) to keep only `parent_argument`, `child_argument`, and `relation`.

# %%
pairs_df.drop(columns=['discussion', 'parent_node_id', 'parent_stance', 'child_node_id', 'child_stance'], inplace=True)
pairs_df
# Out:
#                                           parent_argument  \
# 0       The pharmacy chain is convoluted and deeply re...
# 1       The pharmacy chain is convoluted and deeply re...
# 2       These manufacturers invest billions into R&D t...
# 3       These manufacturers invest billions into R&D t...
# 4       These manufacturers invest billions into R&D t...
# ...                                                   ...
# 197826  According to the word of God in Genesis 1 , hu...
# 197827  The Bible is not a credible source of informat...
# 197828  The Bible is not a credible source of informat...
# 197829  The Bible is not a credible source of informat...
# 197830  Many of the kingdoms and cities  in the Old Te...
#
#                                            child_argument relation
# 0       Spending on pharmaceutical industry lobbying r...  Support
# 1       In 2020 there were 1,500 pharmaceutical lobbyi...  Support
# 2       Diseases from hemophilia to cancer to autoimmu...  Support
# 3       Likely the most efficient way to motivate cont...  Support
# 4       A substantial portion of Research and Developm...   Attack
# ...                                                   ...      ...
# 197826  The Bible is not a credible source of informat...   Attack
# 197827  Due to the age of the Bible and the fact that ...  Support
# 197828  The Bible was written by humans , not a divine...  Support
# 197829  Many of the kingdoms and cities  in the Old Te...   Attack
# 197830  Some aspects of stories can be true without th...   Attack
#
# [197831 rows x 3 columns]

# %% [markdown]
# ### Preprocess Argument Texts
#
# Cleans text (lowercase, removes noise), balances the dataset (undersamples majority class), and filters out short/empty arguments.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.utils import resample
from transformers import BertTokenizer

MAX_TOKENS = 512

class ArgumentDataProcessor:
    """
    Class for preprocessing argumentative data
    """
    def __init__(self):
        self.lemmatizer = WordNetLemmatizer()
        self.stop_words = set(stopwords.words('english'))
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
    
    def clean_text(self, text):
        """
        - Improve the quality of embeddings
        - Reduce noise and improve generalization
        - Standardize input format
        """
        if pd.isna(text):
            return ""
        
        # Lowercase conversion
        text = text.lower()
        
        # Remove special characters but keep important punctuation
        text = re.sub(r'[^\w\s\.\!\?\,\;\:\']', ' ', text)
        
        # Remove multiple spaces
        text = re.sub(r'\s+', ' ', text)
        
        return text.strip()
    
    def truncate_text(self, text, column_name=None):
        """
        Truncate text to MAX_TOKENS tokens for BERT
        Returns the truncated text and logs if truncation happened
        """
        tokens = self.tokenizer.encode(text, add_special_tokens=True)
        if len(tokens) > MAX_TOKENS:
            if column_name:
                print(f"Warning: {column_name} text truncated to {MAX_TOKENS} tokens")
            tokens = tokens[:MAX_TOKENS]
            return self.tokenizer.decode(tokens, skip_special_tokens=True)
        return text
    
    def explore_data(self, df):
        """
        - Understand the class distribution (Support vs Attack balance)
        - Identify outliers (claims that are too short/long)
        - Detect patterns in the dataset
        """
        print("=== DATA EXPLORATION ===")
        print(f"Dataset size: {len(df)}")
        print(f"Columns: {df.columns.tolist()}")
        
        # Relation distribution
        print("\nRelation distribution:")
        relation_counts = df['relation'].value_counts()
        print(relation_counts)
        print(f"Balance ratio: {relation_counts.min() / relation_counts.max():.2f}")
        
        # Argument length statistics
        df['parent_length'] = df['parent_argument'].str.len()
        df['child_length'] = df['child_argument'].str.len()
        
        print(f"\nAverage parent length: {df['parent_length'].mean():.1f}")
        print(f"Average child length: {df['child_length'].mean():.1f}")
        
        # Missing values check
        print("\nMissing values:")
        print(df.isnull().sum())
        
        return df
    
    def process_dataframe(self, df, balance=True, strategy="undersample"):
        print("=== PREPROCESSING ===")
        
        original_size = len(df)

        # Drop duplicates
        df = df.drop_duplicates(subset=['parent_argument','child_argument','relation'])
        dropped = original_size - len(df)
        print(f"Duplicate rows removed: {dropped}")
        original_size = len(df)

        # Drop rows with missing values
        df = df.dropna(subset=['parent_argument','child_argument','relation'])
        dropped = original_size - len(df)
        print(f"Rows with missing values removed: {dropped}")
        original_size = len(df)

        # Clean text
        df['parent_clean'] = df['parent_argument'].apply(self.clean_text)
        df['child_clean'] = df['child_argument'].apply(self.clean_text)

        # Cutting out texts that are too long for BERT
        df['parent_clean'] = df['parent_clean'].apply(lambda x: processor.truncate_text(x, 'parent'))
        df['child_clean'] = df['child_clean'].apply(lambda x: processor.truncate_text(x, 'child'))

        # Drop rows with empty cleaned text
        df = df[(df['parent_clean'].str.len()>0) & (df['child_clean'].str.len()>0)]
        dropped = original_size - len(df)
        print(f"Rows with empty cleaned text removed: {dropped}")
        original_size = len(df)

        # Delete rows with less than 50 characters
        df = df[(df['parent_argument'].str.len() >= 50) & (df['child_argument'].str.len() >= 50)]
        dropped = original_size - len(df)
        print(f"Rows with less than 50 characters removed: {dropped}")
        original_size = len(df)

        # Optional balancing
        if balance:
            counts = df['relation'].value_counts()
            print("Before balancing:", counts.to_dict())
            min_size = counts.min()
            dfs = []
            for label in counts.index:
                dfs.append(resample(
                    df[df['relation']==label],
                    replace=False if strategy=="undersample" else True,
                    n_samples=min_size if strategy=="undersample" else counts.max(),
                    random_state=42
                ))
            df = pd.concat(dfs).sample(frac=1, random_state=42).reset_index(drop=True)
            print("After balancing:", df['relation'].value_counts().to_dict())

        print(f"Final dataset size: {len(df)}")
        return df

processor = ArgumentDataProcessor()
clean_df = processor.explore_data(pairs_df)
clean_df = processor.process_dataframe(pairs_df)
# Out:
# /home/nysek/miniconda3/envs/ddc_project/lib/python3.11/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# === DATA EXPLORATION ===
# Dataset size: 197831
# Columns: ['parent_argument', 'child_argument', 'relation']
#
# Relation distribution:
# relation
# Attack     100470
# Support     97361
# Name: count, dtype: int64
# Balance ratio: 0.97
#
# Average parent length: 134.1
# Average child length: 145.8
#
# Missing values:
# parent_argument    0
# child_argument     0
# relation           0
# parent_length      0
# child_length       0
# dtype: int64
# === PREPROCESSING ===
# Duplicate rows removed: 79612
# Rows with missing values removed: 0
# Rows with empty cleaned text removed: 0
# Rows with less than 50 characters removed: 14594
# Before balancing: {'Attack': 52744, 'Support': 50881}
# After balancing: {'Attack': 50881, 'Support': 50881}
# Final dataset size: 101762

# %% [markdown]
# ### Inspect Random Examples
#
# Prints 50 random argument pairs with their relationships to verify data quality and labeling.

# %%
final_df = clean_df.drop(columns=['parent_argument', 'child_argument', 'parent_length', 'child_length'])

for i in range (0, 50):
    rand_index = final_df.sample(n=1, random_state=i).index[0]
    print(f"\nRandom example {i+1}:")
    print(final_df.iloc[rand_index]['parent_clean'])
    print(final_df.iloc[rand_index]['child_clean'])
    print(final_df.iloc[rand_index]['relation'])

final_df
# Out:
# Random example 1:
# the apostles were clearly more significant than the rest of jesus's disciples.
# only the writings of the apostles were considered worthy to include in the biblical canon.
# Support
#
# Random example 2:
# though the bible states that natural disasters are a result of god's wrath against sinning , science has shown that the cause of natural disasters are set forces of nature that are difficult but not impossible to predict.
# god, as a primary cause of events does not preclude natural secondary causes. the bible's recording of these events and god as primary cause is more about the author's interpretation of events and does not invalidate the historical veracity of the account.
# Attack
#
# Random example 3:
# confucianism according to confucianism, the purpose of life is to get disciplined and educated .
# instead of focusing on individual freedom, confucianism emphasizes self discipline, ritual propriety, and moral uprightness .
# Support
#
# Random example 4:
# the lack of women in leadership roles can be attributed to women making different life choices to men.
# prospects for promotion often come at a time when women choose to have families . with expensive childcare, and few meaningful family friendly workplaces, few of those talented women last long enough to make it to the top.
# Support
#
# Random example 5:
# states may have to take children out of the custody of their parents to enforce such a ban.
# if parents are inappropriately and illegally homeschooling their children, taking them out of their parents' custody may be in the children's best interests.
# Attack
#
# Random example 6:
# there are circumstances in which we must put animal lives ahead of human lives.
# sacrificing or rescuing an animal over a human is an individual decision at best.
# Attack
#
# Random example 7:
# obesity creates negative externalities that harm society.
# shaming obesity, and the policies that accompany it, will similarly have negative externalities.
# Attack
#
# Random example 8:
# genetically modified crops can help mitigate world hunger .
# crops are often genetically modified in ways that allow for increased crop yields, increasing the amount of food that the world is able to produce.
# Support
#
# Random example 9:
# it is easier to protect people from exploitation when all begging is banned, as opposed to having to inquire and investigate if a specific incident of begging is exploitative.
# however, this runs the risk of denying some honest beggars their only ability to earn their living.
# Attack
#
# Random example 10:
# data from several countries shows that public opinion is firmly in favour of mandating mask wearing.
# even if everyone is in favour of wearing masks in theory, not everyone can afford to buy masks.
# Attack
#
# Random example 11:
# government monopolies are not necessarily a bad thing, when their primary goal is not to maximise shareholder capital but rather to maximise citizens' living standards.
# monopolies are always bad, because they are the opposite of competitiveness which is unquestionably a good thing.
# Attack
#
# Random example 12:
# typically, people's ability to interpret non verbal communication is poor . given this, approaching someone is essential to assess a stranger's interest.
# some people struggle to perceive and interpret body language effectively, meaning they must approach someone to discern their interest in sex.
# Support
#
# Random example 13:
# gender is not a good indicator of one's attributes, like their social role or skills. therefore, it would be better to organize society around these attributes, rather than gender.
# organizing society on the basis of social roles could, with time, turn rigid and evolve into a hierarchical system like the caste system .
# Attack
#
# Random example 14:
# a paper funded by by a group whose members included coca cola, hershey, red bull and oreo cookie maker mondelez published a study that downplayed the harms of excess sugar intake.
# such actions do not define the entirety of the corporate world. marc inc. publicly denounced the findings of this paper.
# Attack
#
# Random example 15:
# organized religions discourage personal exploration and spirituality.
# most religions are limited to obsolete philosophical and spiritual concepts that contradict a modern understanding of existence.
# Support
#
# Random example 16:
# adding a tax on meat would make the prices of imported meat cheaper due to dumping and predatory pricing pushing out domestic industries from the market.
# measures such as eco tariffs and import related policy can solve this issue. imported meat would need to verifiably meet environmental and animal welfare standards and or needs to pass a sufficiently high tax barrier.
# Attack
#
# Random example 17:
# western liberal high income countries accepting vulnerable refugees may fuel western saviourism and cultural imperialism , which are harmful overall to refugees.
# in western saviourist terms, the taking in of refugees by high income countries may contribute to the imperialist erasure and disempowerment of marginalised people and their identities, as predominantly wealthy, white countries 'save' refugees by assimilating them into their culture and way of life p. 3 .
# Support
#
# Random example 18:
# though religion may be the foundation of many civilizations, increased economic development , education and urbanization lead countries to be more secular .
# countries that are more secular and tolerant, with socially liberal laws , often opposed by religion, are more likely to have more economic growth.
# Support
#
# Random example 19:
# if judicial systems did not presume individuals have free will, there would be no reason to claim they have responsibility for their actions.
# in many legal systems, individuals with significantly impaired autonomy, as with cases involving coercion or cognitive impairment p. 1 , are often considered less responsible for their actions and receive accommodations or reduced sentences.
# Support
#
# Random example 20:
# breastfeeding should not hurt . if it does, something is going wrong and the mother should fix the problem or find the medical reason for the pain.
# if there is a medical reason for the pain, this would count as one of the exemptions see discussion description allowing a mother to use formula instead.
# Support
#
# Random example 21:
# if morality is an inescapable consequence of deliberate choice but different subgroups in society have different moral rules, then the only way to behave 'morally' is to associate with like minded people or adapt your behavior to local rules. neither of these options require an centralised authority like religion.
# in a population, people discuss their moral values and reevaluate them according to said discussion, and this is done in ways where people mix and communicate with people who only share certain similar views, while disagreeing on others. change in societal beliefs occurs through this.
# Attack
#
# Random example 22:
# increasing leisure time shares available paid work among citizens more evenly and reduces inequality.
# better paid job requires competences so sharing will be possible only for blue collars.
# Attack
#
# Random example 23:
# monarchs' support of issues overlooked by the government can help these causes reach the national agenda.
# in some instances, monarchs are able to offer symbolic actions of peace and apologies for past injustice more readily than elected politicians. this provides cathartic change from past injustice, when often parliament might have stayed silent.
# Support
#
# Random example 24:
# muslim women who choose to remain unmarried are often viewed as suspicious, immoral, or dissatisfied pp. 2 3 .
# single muslim women are often subjected to judgment, leading to self confidence issues and ostracization. this makes remaining single an unappealing option.
# Support
#
# Random example 25:
# when one sins in ignorance, they should sacrifice a young bull leviticus 4:3 4 , sacrifice a ram leviticus 5:15 16 , and sacrifice a young female goat numbers 15:27 28 .
# leviticus 5:15 16, unlike the other passages, is specifically about sinning unintentionally in regard to any of the lord s holy things.
# Attack
#
# Random example 26:
# the fact that moral disagreement is so intractable and cannot seem to be resolved through rational argumentation indicates that moral disagreements are a reflection of fundamentally contrary emotional attitudes, rather than intellectual disagreements over facts.
# it is difficult to get a person to accept an argument when self interest is opposed. stated more colloquially, it's hard to get a man to understand something when his paycheck depends on his not understanding. just because a person does not accept an argument does not render it invalid, nor does it demonstrate that the argument is subjective. a listener's emotional commitment to a position is not relevant.
# Attack
#
# Random example 27:
# perceptions and aims affect facts in the sense that facts are distilled through somebody's experience of the world.
# quantitiative findings are relatively easy to replicate by other scientists.
# Attack
#
# Random example 28:
# the full text reads: messiah ben yosef who was killed in the war of gog from the land of magog prior to the ultimate redemption with the coming of messiah ben david. this clearly doesn't refer to jesus of nazareth.
# jesus was meant to be the messiah ben of the line of david, not messiah ben josef.
# Support
#
# Random example 29:
# musk is rolling back measures against misinformation, disinformation and misleading propaganda .
# twitter has reverted its covid misinformation policy since elon musk's takeover.
# Support
#
# Random example 30:
# a socialist economy motivates people to better themselves and their community. capitalist society focuses on capital gain, causing people to earn excessive amounts of money at the expense of others.
# those involved in activities that would help others tend to be underpaid and overworked in capitalist systems.
# Support
#
# Random example 31:
# nuclear power plants are vulnerable to accidental damage and deliberate attacks.
# rogue states and or separatist forums can convert nuclear civilian energy projects to nuclear projects for war warlike purpose thus posing a threat to others.
# Support
#
# Random example 32:
# while britain had a relatively low homicide rate before banning firearms in 1996, the murder rate in britain increased after the ban and spiked in 2002 2003 before returning to normal.
# in 2002, the uk experienced its highest homicide rate of the last 25 years, at 1.87 deaths per 100,000 people.
# Support
#
# Random example 33:
# activist feminist organizations in islamic countries are promoting change for women from within the fold of islam p. 26 .
# the muslim women awards are devoted to celebrating the achievements of muslim women in the uk.
# Support
#
# Random example 34:
# obviously, if the human brain is not butting up against a physical upper limit of what computation physical objects can do, then a physical object can exist which exceeds every human brain on every dimension, which would be a general superintelligence.
# while that physical object may exist, if it is to exceed human intelligence on every dimension in a general intelligence way, that may only be possible for biological objects where the part synthetic would then be very questionable.
# Attack
#
# Random example 35:
# rey is a distinct character from luke, and the idea that her successes and failures have to be measured against his is ridiculous.
# like luke, she left before completing her jedi training against the will of her master, to face a vastly superior enemy snoke and kylo . where luke was resoundingly defeated by vader, rey emerged completely unscathed. if kylo is meant to be her counterbalance in the force, and has received significant training, he should have enjoyed something resembling a victory over her by this point.
# Attack
#
# Random example 36:
# the first amendment , which guarantees free expression in the u.s., has a number of exceptions.
# it is impractical to suggest that a law should have no limitations.
# Attack
#
# Random example 37:
# it is one of the many ways in which parents associate a particular gender to a baby from birth.
# this is problematic since it bypasses the baby's right to express their own gender identity.
# Support
#
# Random example 38:
# in order to create a politically united europe, it will be necessary for countries to adopt similar political systems and abolish monarchies.
# political unity is crucial for europe to maintain peace and stability in a globalized world.
# Support
#
# Random example 39:
# a country's enrollment in the imf's program instills investor confidence in the stability of the current economy, encouraging investment and the retention of investments.
# sri lanka witnessed a rise in foreign direct investment following a bailout from the imf .
# Support
#
# Random example 40:
# crowdsourcing is direct participation not like traditional direct democracy efforts that use popular votes to follow the will of the majority. also this forum would operate inside our existing systems and shouldn t be assumed to be any more anti minority than our existing systems.
# a crowd sourced government policy forum that scored laws by how well they protected the rights of everyone could protect the rights of minorities.
# Support
#
# Random example 41:
# even if people circumvent travel restrictions, as long as these restrictions reduce the number of visitors, they would help in reducing the spread of infections.
# the degree of passenger volume has a large impact on the reduction of spread.
# Support
#
# Random example 42:
# the incredibly popular novel and film '50 shades of grey' portrayed an abusive and inconsiderate depiction of bdsm.
# the novel and film series have a large female fan base , suggesting that many do not object to even the beyond bdsm practices of these fictional works but rather are interested or attracted by them.
# Attack
#
# Random example 43:
# balance is key. in the us, there are more than 1,500 monuments to the confederacy , including plaques and place names. approximately 1,000 can be removed or moved to museums, leaving around 500 for historical reference. society should not attempt to glorify the confederacy by the sheer quantity, but the past should never be erased either.
# removing symbols and glorifications does not erase the past .
# Attack
#
# Random example 44:
# a crowdsourcing system may be difficult to utilize for those who are handicapped.
# it is easier for people with disabilities to get on the internet than it is for them to drive across town or the country in order to participate in a live debate.
# Attack
#
# Random example 45:
# leaders are often more educated than the average citizen and hence are more likely to understand the significance of climate change.
# the insulation provided by the wealth and power politicians have clouds their ability to understand the significance of climate change.
# Attack
#
# Random example 46:
# it is likely that individuals will continue to believe and spread lies amongst themselves after misinformation is banned.
# if misinformation spreads outside of the confines of easily and widely monitored public spaces like social media, it may be even harder to stop.
# Support
#
# Random example 47:
# the singular 'they' has been used for hundreds of years by english speakers and even writers like shakespeare, austen, shaw.
# those instances of 'they' referred to an unspecified person, so the examples cited aren't the same as employing 'they' to specify a person of undisclosed gender.
# Attack
#
# Random example 48:
# horus didn't have 12 disciples, mithra wasn't born at 25th december and most of other claims in this article are also false. this article is unsupported and debunked .
# many religions exist with many savior or hero figures in each religion. if differences are ignored one can find superficial similarities between unrelated religious figures by chance alone.
# Support
#
# Random example 49:
# doing scientific work requires resources and money. the bias doesn't not have to appear in the research itself, but rather it appears in what is selected to research.
# science is most often funded by government or institutional grants and the decision on what to fund, or more importantly what not to fund, is politically or commercially motivated. therefore science is politically influenced.
# Support
#
# Random example 50:
# religion was instrumental in developing systems of charity.
# religions founded, financed, and staffed hospitals .
# Support
#        relation                                       parent_clean  \
# 0        Attack  in a 2018 straw poll in washington's 10th cong...
# 1       Support  there are sufficient safeguards in place preve...
# 2       Support  a recent change in us law means that, as of ju...
# 3        Attack  marriage has been shown to reinforce the gende...
# 4        Attack  human rights are not laws of the universe but ...
# ...         ...                                                ...
# 101757   Attack  personal health records are private informatio...
# 101758  Support  employers are likely to become better at deali...
# 101759  Support  there is no such universal and objective right...
# 101760   Attack  in some nations, private school fees enjoy cha...
# 101761   Attack  societies and legal systems depend on the noti...
#
#                                               child_clean
# 0       if score voting were actually used for real wo...
# 1       the media, which is widely regarded as the fou...
# 2       some us women are being discriminated against ...
# 3       the correlation this study found might a littl...
# 4       we only experience human consciousness, but we...
# ...                                                   ...
# 101757  patient information can be used by authorized ...
# 101758  if people are able to be open about a physical...
# 101759  you could claim that human rights are neither ...
# 101760  it is unlikely that the taxes gained by removi...
# 101761  if the illusion of moral choices were convinci...
#
# [101762 rows x 3 columns]

# %% [markdown]
# ### Save Final Dataset
#
# Exports the cleaned DataFrame to a CSV file for embedding generation and model training.

# %%
from sklearn.model_selection import train_test_split

def make_balanced_sample(df, n, seed=42):
    # Stratified sampling sur la colonne 'relation'
    sample, _ = train_test_split(
        df,
        train_size=n,
        stratify=df['relation'],
        random_state=seed
    )
    return sample.reset_index(drop=True)

# 100k version
df_100k = make_balanced_sample(final_df, 50_000)
df_100k.to_csv('../../data/kialo/kialo-pairs-50k.csv', index=False)

# 50k version
df_50k = make_balanced_sample(final_df, 25_000)
df_50k.to_csv('../../data/kialo/kialo-pairs-25k.csv', index=False)

# 10k version
df_10k = make_balanced_sample(final_df, 10_000)
df_10k.to_csv('../../data/kialo/kialo-pairs-10k.csv', index=False)
